# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read all data 
A = pd.read_html('Report16Jul2021120443.html')
#A

# %%
# choosing the data that we will use 
A1=A[11]
#A1

# %%
# changing the first row to be a header for all data
new_header1 = A1.iloc[0] #grab the first row for the header
A2 = A1[1:] #take the data less the header row
A2.columns = new_header1 #set the header row as the df header
A2 = A2.reset_index(drop=True)#reseting index
A2
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  61559  59148  60425  59856   734948          0.00
# 1     14 Jul 2021  61743  59602  59602  60599  1309576          0.00
# 2     13 Jul 2021  60480  59216  59352  59643  1369993          0.00
# 3     12 Jul 2021  59492  57788  58985  59452  1130268          0.00
# 4     09 Jul 2021  58967  56806  56966  58800  1455624          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  15512  14598  14822  14929  4887309          0.00
# 1246  20 Jul 2016  14822  13717  14734  14384  6229779          0.00
# 1247  19 Jul 2016  15509  15025  15465  15399  2915865          0.00
# 1248  18 Jul 2016  15747  15300  15744  15737  1342389          0.00
# 1249  15 Jul 2016  16075  15699  16000  15846  3501534          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.01  6.75  14.81  2.01
# 1                   0.00                   1.98  6.67  15.00  1.98
# 2                   0.00                   2.01  6.77  14.76  2.01
# 3                   0.00                   2.02  6.80  14.71  2.02
# 4                   0.00                   2.04  6.87  14.55  2.04
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   2.26  2.48  40.32  2.26
# 1246                0.00                   2.35  2.57  38.84  2.35
# 1247                0.00                   2.19  2.40  41.59  2.19
# 1248                0.00                   2.14  2.35  42.50  2.14
# 1249                0.00                   2.13  2.34  42.79  2.13
#
# [1250 rows x 12 columns]

# %%
Indicator = A2.copy()#creating a copy
Indicator
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  61559  59148  60425  59856   734948          0.00
# 1     14 Jul 2021  61743  59602  59602  60599  1309576          0.00
# 2     13 Jul 2021  60480  59216  59352  59643  1369993          0.00
# 3     12 Jul 2021  59492  57788  58985  59452  1130268          0.00
# 4     09 Jul 2021  58967  56806  56966  58800  1455624          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  15512  14598  14822  14929  4887309          0.00
# 1246  20 Jul 2016  14822  13717  14734  14384  6229779          0.00
# 1247  19 Jul 2016  15509  15025  15465  15399  2915865          0.00
# 1248  18 Jul 2016  15747  15300  15744  15737  1342389          0.00
# 1249  15 Jul 2016  16075  15699  16000  15846  3501534          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.01  6.75  14.81  2.01
# 1                   0.00                   1.98  6.67  15.00  1.98
# 2                   0.00                   2.01  6.77  14.76  2.01
# 3                   0.00                   2.02  6.80  14.71  2.02
# 4                   0.00                   2.04  6.87  14.55  2.04
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   2.26  2.48  40.32  2.26
# 1246                0.00                   2.35  2.57  38.84  2.35
# 1247                0.00                   2.19  2.40  41.59  2.19
# 1248                0.00                   2.14  2.35  42.50  2.14
# 1249                0.00                   2.13  2.34  42.79  2.13
#
# [1250 rows x 12 columns]

# %%
Indicator['Date'] = pd.to_datetime(Indicator.Date)#changing date format
Indicator
# Out:
# 0          Date   High    Low   Open  Close   Volume InterestYield  \
# 0    2021-07-15  61559  59148  60425  59856   734948          0.00
# 1    2021-07-14  61743  59602  59602  60599  1309576          0.00
# 2    2021-07-13  60480  59216  59352  59643  1369993          0.00
# 3    2021-07-12  59492  57788  58985  59452  1130268          0.00
# 4    2021-07-09  58967  56806  56966  58800  1455624          0.00
# ...         ...    ...    ...    ...    ...      ...           ...
# 1245 2016-07-21  15512  14598  14822  14929  4887309          0.00
# 1246 2016-07-20  14822  13717  14734  14384  6229779          0.00
# 1247 2016-07-19  15509  15025  15465  15399  2915865          0.00
# 1248 2016-07-18  15747  15300  15744  15737  1342389          0.00
# 1249 2016-07-15  16075  15699  16000  15846  3501534          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.01  6.75  14.81  2.01
# 1                   0.00                   1.98  6.67  15.00  1.98
# 2                   0.00                   2.01  6.77  14.76  2.01
# 3                   0.00                   2.02  6.80  14.71  2.02
# 4                   0.00                   2.04  6.87  14.55  2.04
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   2.26  2.48  40.32  2.26
# 1246                0.00                   2.35  2.57  38.84  2.35
# 1247                0.00                   2.19  2.40  41.59  2.19
# 1248                0.00                   2.14  2.35  42.50  2.14
# 1249                0.00                   2.13  2.34  42.79  2.13
#
# [1250 rows x 12 columns]

# %%
#making it floats for easy calculation
Indicator['High']=Indicator.High.astype('float')
Indicator['Close']=Indicator.Close.astype('float')
Indicator['Low']=Indicator.Low.astype('float')
Indicator['Open']=Indicator.Open.astype('float')

# %%
#deleting other columns not used 
del Indicator['Volume'],Indicator['TotalDistributionYield'], Indicator['InterestYield'], Indicator['CapitalPaymentYield'], Indicator['EY'], Indicator['DY'], Indicator['P/E']
#Indicator

# %%
Indicator.describe()
# Out:
# 0              High           Low          Open         Close
# count   1250.000000   1250.000000   1250.000000   1250.000000
# mean   33916.890400  32968.853600  33411.796800  33438.470400
# std    12146.548628  11808.654315  11968.245949  11975.374482
# min    14802.000000  13717.000000  14627.000000  14384.000000
# 25%    25383.250000  24497.750000  24911.000000  24840.750000
# 50%    32248.500000  31288.000000  31799.500000  31800.500000
# 75%    40100.000000  39167.000000  39600.000000  39646.250000
# max    69347.000000  67075.000000  68316.000000  67770.000000

# %%
Indicator['Direct'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #generating target variable
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct
# 0    2021-07-15  61559.0  59148.0  60425.0  59856.0     NaN
# 1    2021-07-14  61743.0  59602.0  59602.0  60599.0   743.0
# 2    2021-07-13  60480.0  59216.0  59352.0  59643.0  -956.0
# 3    2021-07-12  59492.0  57788.0  58985.0  59452.0  -191.0
# 4    2021-07-09  58967.0  56806.0  56966.0  58800.0  -652.0
# ...         ...      ...      ...      ...      ...     ...
# 1245 2016-07-21  15512.0  14598.0  14822.0  14929.0   499.0
# 1246 2016-07-20  14822.0  13717.0  14734.0  14384.0  -545.0
# 1247 2016-07-19  15509.0  15025.0  15465.0  15399.0  1015.0
# 1248 2016-07-18  15747.0  15300.0  15744.0  15737.0   338.0
# 1249 2016-07-15  16075.0  15699.0  16000.0  15846.0   109.0
#
# [1250 rows x 6 columns]

# %%
sig = []
for h in range (len(Indicator)):
    if Indicator['Direct'][h] > 0: #values satisfy a sell
        sig.append(3)
    else:
        sig.append(1) #buy 
    
Indicator['signal'] = sig
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal
# 0    2021-07-15  61559.0  59148.0  60425.0  59856.0     NaN       1
# 1    2021-07-14  61743.0  59602.0  59602.0  60599.0   743.0       3
# 2    2021-07-13  60480.0  59216.0  59352.0  59643.0  -956.0       1
# 3    2021-07-12  59492.0  57788.0  58985.0  59452.0  -191.0       1
# 4    2021-07-09  58967.0  56806.0  56966.0  58800.0  -652.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1245 2016-07-21  15512.0  14598.0  14822.0  14929.0   499.0       3
# 1246 2016-07-20  14822.0  13717.0  14734.0  14384.0  -545.0       1
# 1247 2016-07-19  15509.0  15025.0  15465.0  15399.0  1015.0       3
# 1248 2016-07-18  15747.0  15300.0  15744.0  15737.0   338.0       3
# 1249 2016-07-15  16075.0  15699.0  16000.0  15846.0   109.0       3
#
# [1250 rows x 7 columns]

# %%
def RSI(value):
    '''
    The function calculates the relative strength index parameters 
    to be used to calculate 14_day rsi values
    '''
    up = value[value>0].mean()
    down = -value[value<0].mean()
    return (100 * up / (up + down))

Indicator['Direction'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #adding momentum
Indicator['RSI_14D'] = Indicator['Direction'].rolling(center=False, window=14).apply(RSI) #14D RSI

# %%
#Indicator['RSI_14D']

# %%
l = []
for i in range (len(Indicator)):
    if Indicator['RSI_14D'][i] >= 28 and Indicator['RSI_14D'][i] <= 30: # values below the signal line of 30 oversold
        l.append(1) #buy
    elif Indicator['RSI_14D'][i] >= 31 and Indicator['RSI_14D'][i] <= 69:
        l.append(2) #hold
    elif Indicator['RSI_14D'][i] >= 70:
        l.append(3)#sell
    else:
        l.append(2) #hold signal
Indicator['RSI_sig'] = l

# %%
sns.countplot(x = 'RSI_sig', data=pd.DataFrame(Indicator), hue='RSI_sig')
#plt.savefig("aspen_rsicount")
plt.show()
Indicator['RSI_sig'].value_counts() #counts according to signal code
# Out:
# 2    1190
# 3      35
# 1      25
# Name: RSI_sig, dtype: int64

# %%
r = Indicator['RSI_14D']
h = [0,1300]
b = [30,30]
f = plt.plot(r, label = 'RSI_14D')
e = [70,70]
g = plt.plot(h,b,h,e) + f
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_rsi")
plt.show(g)

# %%
n=21
Indicator['STOK'] = ((Indicator['Close'] - Indicator['Low'].rolling(window=n,center=False).mean()) /
                     (Indicator['High'].rolling(window=n, center=False).max() - 
                      Indicator['Low'].rolling(window=n, center=False).min())) * 100 #D% stochastic
Indicator['STOD'] = Indicator['STOK'].rolling(window = 7, center=False).mean()  #K% stochastic

# %%
m = []
for i in range (len(Indicator)):
    if Indicator['STOK'][i] >= 28 and Indicator['STOK'][i]<=30:
        m.append(1) #buy
    elif Indicator['STOK'][i] > 30 and Indicator['STOK'][i] <= 69:
        m.append(2) #sell    
    elif Indicator['STOK'][i] >= 70:
        m.append(3) #sell
    else:
        m.append(2) #hold
Indicator['STO_sig'] = m

# %%
sns.countplot(x = 'STO_sig', data=pd.DataFrame(Indicator), hue='STO_sig')
#plt.savefig("aspen_stocount")
plt.show()
Indicator['STO_sig'].value_counts()
# Out:
# 2    1226
# 1      24
# Name: STO_sig, dtype: int64

# %%
t = Indicator['STOD']
j = Indicator['STOK']
u = plt.plot(t, label = 'STOD')
s = plt.plot(j, label = 'STOK')
h = [0,1300]
b = [30,30]
e = [70,70]
g = plt.plot(h,e,h,b) + u + s
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_sto")
plt.show()

# %%
Indicator['EMA_10'] = Indicator['Close'].ewm(span=10,adjust=False,min_periods=1).mean() #50day exponential ma
Indicator['EMA_30'] = Indicator['Close'].ewm(span=20,adjust=False,min_periods=1).mean() #100day exponential ma
Indicator['EMA_90'] = Indicator['Close'].ewm(span=90,adjust=False,min_periods=1).mean() #200day exponential ma

# %%
# append 1 for a buy, 0 for a sell and 2 for hold and NaN
n = []
for i in range (len(Indicator)):
    if Indicator['EMA_10'][i] < Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(1) #buy
    elif Indicator['EMA_10'][i] > Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(3) #sell
    elif Indicator['EMA_10'][i] == Indicator['EMA_30'][i] == Indicator['EMA_90'][i]:
        n.append(2)  #hold      
    else:
        n.append(2)#hold
Indicator['EMA_sig'] = n

# %%
sns.countplot(x = 'EMA_sig', data=pd.DataFrame(Indicator), hue='EMA_sig')
#plt.savefig("aspen_emacount")
plt.show()
Indicator['EMA_sig'].value_counts()
# Out:
# 1    810
# 3    439
# 2      1
# Name: EMA_sig, dtype: int64

# %%
# buy if 50EMA line cuts the other two EMA lines from above and moves below both the EMAs
# sell if 50EMA line cuts the other two EMA lines from below and moves above both the EMAs
a = Indicator['EMA_10'] #50 day exponential moving average
b = Indicator['EMA_30'] #100 day exponential moving average
c = Indicator['EMA_90'] #200 day exponential moving average
d = plt.plot(a, label = 'EMA_10' ) + plt.plot(b, label = 'EMA_30') + plt.plot(c, label = 'EMA_90')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_ema")
plt.show(d)

# %%
Indicator['26_ema'] = Indicator['Close'].ewm(span=26,adjust=True,ignore_na=False).mean() #26day ema
Indicator['12_ema'] = Indicator['Close'].ewm(span=12,adjust=True,ignore_na=False).mean() #12day ema
Indicator['MACD'] = Indicator['12_ema'] - Indicator['26_ema'] #macd
Indicator['9EMA_MACD'] = Indicator['MACD'].ewm(span=9,adjust=True,ignore_na=False).mean() #9daymacd_ema
#Indicator

# %%
f = []
for i in range (len(Indicator)):
    if Indicator['MACD'][i] > Indicator['9EMA_MACD'][i]:
        f.append(1) #buy
    elif Indicator['MACD'][i] < Indicator['9EMA_MACD'][i]:
        f.append(3) #sell
    elif Indicator['MACD'][i] == Indicator['9EMA_MACD'][i]:
        f.append(2) #
    else:
        f.append(2)
Indicator['MACD_sig'] = f

# %%
sns.countplot(x = 'MACD_sig', data=pd.DataFrame(Indicator), hue='MACD_sig')
#plt.savefig("aspen_macdcount")
plt.show()
Indicator['MACD_sig'].value_counts()
# Out:
# 3    656
# 1    593
# 2      1
# Name: MACD_sig, dtype: int64

# %%
q = Indicator['9EMA_MACD']
e = Indicator['MACD']
z = [0,1300]
x = [0,0]
r = plt.plot(z,x)+ plt.plot(e, label = 'MACD') +plt.plot(q, label = '9EMA_MACD')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_macd")
plt.show(r)

# %%
Indicator[513:1110]
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 513  2019-06-28  40351.0  39361.0  39626.0  40260.0   -96.0       1
# 514  2019-06-27  40000.0  39543.0  39800.0  39626.0  -634.0       1
# 515  2019-06-26  39878.0  39289.0  39800.0  39613.0   -13.0       1
# 516  2019-06-25  40109.0  39288.0  39604.0  39716.0   103.0       3
# 517  2019-06-24  39780.0  39120.0  39300.0  39659.0   -57.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1105 2017-02-10  22659.0  22101.0  22300.0  22541.0  -632.0       1
# 1106 2017-02-09  22889.0  21505.0  22375.0  21600.0  -941.0       1
# 1107 2017-02-08  23200.0  22017.0  22600.0  22250.0   650.0       3
# 1108 2017-02-07  22500.0  22190.0  22235.0  22390.0   140.0       3
# 1109 2017-02-06  22473.0  22110.0  22290.0  22164.0  -226.0       1
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 513       -96.0  74.568517        3  ...        2  39102.695790  38174.468554
# 514      -634.0  70.695913        3  ...        2  39197.842010  38312.709644
# 515       -13.0  70.975919        3  ...        2  39273.325281  38436.546821
# 516       103.0  65.949343        2  ...        2  39353.811593  38558.399505
# 517       -57.0  69.692091        2  ...        2  39409.300395  38663.218599
# ...         ...        ...      ...  ...      ...           ...           ...
# 1105     -632.0  51.061008        2  ...        2  22133.258350  21439.811552
# 1106     -941.0  47.340236        2  ...        2  22036.302286  21455.067594
# 1107      650.0  50.308872        2  ...        1  22075.156416  21530.775443
# 1108      140.0  50.834760        2  ...        2  22132.400704  21612.606353
# 1109     -226.0  50.574957        2  ...        2  22138.146030  21665.120033
#
# 0           EMA_90  EMA_sig        26_ema        12_ema         MACD  \
# 513   36305.288853        3  37702.818503  38903.405694  1200.587191
# 514   36378.271516        3  37845.276392  39014.574049  1169.297657
# 515   36449.364449        3  37976.218881  39106.639580  1130.420698
# 516   36521.158637        3  38105.091557  39200.387337  1095.295780
# 517   36590.122184        3  38220.195886  39270.943131  1050.747245
# ...            ...      ...           ...           ...          ...
# 1105  20208.807186        3  21158.250829  21965.017725   806.766896
# 1106  20239.382853        3  21190.972990  21908.861152   717.888162
# 1107  20283.572241        3  21269.419435  21961.344052   691.924616
# 1108  20329.867356        3  21352.425403  22027.291121   674.865718
# 1109  20370.177964        3  21412.542040  22048.323256   635.781216
#
# 0       9EMA_MACD  MACD_sig
# 513   1095.398022         1
# 514   1110.177949         1
# 515   1114.226499         1
# 516   1110.440355         3
# 517   1098.501733         3
# ...           ...       ...
# 1105   620.999682         1
# 1106   640.377378         1
# 1107   650.686826         1
# 1108   655.522604         1
# 1109   651.574326         3
#
# [597 rows x 22 columns]

# %%
start = Indicator[Indicator['Date']=='2020-01-31'].index[0]
end = Indicator[Indicator['Date']=='2017-02-07'].index[0]

#Show the sliced df (from 2017-01-07 to 2017-01-14)
Indicator.loc[start:end]
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 364  2020-01-31  39647.0  38860.0  39151.0  39063.0   410.0       3
# 365  2020-01-30  39212.0  38335.0  38790.0  39177.0   114.0       3
# 366  2020-01-29  39490.0  38980.0  38980.0  39054.0  -123.0       1
# 367  2020-01-28  39480.0  38386.0  38648.0  38946.0  -108.0       1
# 368  2020-01-27  39800.0  38186.0  39800.0  38888.0   -58.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1104 2017-02-13  23313.0  22732.0  22906.0  23173.0   281.0       3
# 1105 2017-02-10  22659.0  22101.0  22300.0  22541.0  -632.0       1
# 1106 2017-02-09  22889.0  21505.0  22375.0  21600.0  -941.0       1
# 1107 2017-02-08  23200.0  22017.0  22600.0  22250.0   650.0       3
# 1108 2017-02-07  22500.0  22190.0  22235.0  22390.0   140.0       3
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 364       410.0  47.373579        2  ...        2  39501.767480  38716.833574
# 365       114.0  46.866031        2  ...        2  39442.718847  38760.658948
# 366      -123.0  46.186131        2  ...        2  39372.042693  38788.596191
# 367      -108.0  43.796778        2  ...        2  39294.580385  38803.587030
# 368       -58.0  46.045165        2  ...        2  39220.656679  38811.626360
# ...         ...        ...      ...  ...      ...           ...           ...
# 1104      281.0  55.032330        2  ...        2  22042.649094  21323.896978
# 1105     -632.0  51.061008        2  ...        2  22133.258350  21439.811552
# 1106     -941.0  47.340236        2  ...        2  22036.302286  21455.067594
# 1107      650.0  50.308872        2  ...        1  22075.156416  21530.775443
# 1108      140.0  50.834760        2  ...        2  22132.400704  21612.606353
#
# 0           EMA_90  EMA_sig        26_ema        12_ema         MACD  \
# 364   35885.395195        3  38024.018728  39442.889057  1418.870329
# 365   35957.738158        3  38109.424748  39401.983048  1292.558300
# 366   36025.787869        3  38179.393285  39348.447194  1169.053909
# 367   36089.968355        3  38236.178968  39286.532241  1050.353274
# 368   36151.463556        3  38284.462007  39225.219589   940.757582
# ...            ...      ...           ...           ...          ...
# 1104  20156.398359        3  21047.630896  21860.293675   812.662779
# 1105  20208.807186        3  21158.250829  21965.017725   806.766896
# 1106  20239.382853        3  21190.972990  21908.861152   717.888162
# 1107  20283.572241        3  21269.419435  21961.344052   691.924616
# 1108  20329.867356        3  21352.425403  22027.291121   674.865718
#
# 0       9EMA_MACD  MACD_sig
# 364   1956.291975         3
# 365   1823.545240         3
# 366   1692.646974         3
# 367   1564.188234         3
# 368   1439.502103         3
# ...           ...       ...
# 1104   574.557879         1
# 1105   620.999682         1
# 1106   640.377378         1
# 1107   650.686826         1
# 1108   655.522604         1
#
# [745 rows x 22 columns]

# %% [markdown]
# # Machine Learning

# %%
Database = Indicator[['EMA_10', 'RSI_14D', 'MACD', 'STOK','signal']]
Database
# Out:
# 0           EMA_10    RSI_14D        MACD       STOK  signal
# 0     59856.000000        NaN    0.000000        NaN       1
# 1     59991.090909        NaN   16.669872        NaN       3
# 2     59927.801653        NaN   -8.404777        NaN       1
# 3     59841.292261        NaN  -26.499222        NaN       1
# 4     59651.966396        NaN  -61.718178        NaN       1
# ...            ...        ...         ...        ...     ...
# 1245  14987.882608  48.847926 -243.480321  -1.360153       3
# 1246  14878.085771  47.101725 -277.177869 -21.716901       1
# 1247  14972.797449  58.669199 -219.451698  20.779581       3
# 1248  15111.743367  58.854813 -144.760805  34.445039       3
# 1249  15245.244573  54.509228  -75.897446  37.615679       3
#
# [1250 rows x 5 columns]

# %%
#correlation
g = Database.corr()
g.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
# #T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col0,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col1,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col2,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col3,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col4{
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col1{
#             background-color:  #0c3d73;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col2{
#             background-color:  #0d3f76;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col3,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col4,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col0,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col1,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col2{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col4{
#             background-color:  #08366a;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col0{
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col2{
#             background-color:  #d8e9f1;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col3{
#             background-color:  #f7f6f6;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col0,#T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col0{
#             background-color:  #15508d;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col1{
#             background-color:  #e1edf3;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col3{
#             background-color:  #fcdfcf;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col4{
#             background-color:  #114781;
#             color:  #f1f1f1;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col1{
#             background-color:  #f9ebe3;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col2{
#             background-color:  #fddcc9;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col4{
#             background-color:  #a2cde3;
#             color:  #000000;
#         }#T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col3{
#             background-color:  #7bb6d6;
#             color:  #000000;
#         }</style><table id="T_e04ddfee_0452_11ec_9634_e454e890cb7d" ><thead>    <tr>        <th class="index_name level0" >0</th>        <th class="col_heading level0 col0" >EMA_10</th>        <th class="col_heading level0 col1" >RSI_14D</th>        <th class="col_heading level0 col2" >MACD</th>        <th class="col_heading level0 col3" >STOK</th>        <th class="col_heading level0 col4" >signal</th>    </tr>    <tr>        <th class="index_name level0" >0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e04ddfee_0452_11ec_9634_e454e890cb7dlevel0_row0" class="row_heading level0 row0" >EMA_10</th>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col1" class="data row0 col1" >0.008329</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col2" class="data row0 col2" >0.057264</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col3" class="data row0 col3" >0.058067</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow0_col4" class="data row0 col4" >-0.002424</td>
#             </tr>
#             <tr>
#                         <th id="T_e04ddfee_0452_11ec_9634_e454e890cb7dlevel0_row1" class="row_heading level0 row1" >RSI_14D</th>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col0" class="data row1 col0" >0.008329</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col2" class="data row1 col2" >0.436062</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col3" class="data row1 col3" >0.532161</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow1_col4" class="data row1 col4" >-0.016279</td>
#             </tr>
#             <tr>
#                         <th id="T_e04ddfee_0452_11ec_9634_e454e890cb7dlevel0_row2" class="row_heading level0 row2" >MACD</th>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col0" class="data row2 col0" >0.057264</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col1" class="data row2 col1" >0.436062</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col3" class="data row2 col3" >0.608471</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow2_col4" class="data row2 col4" >0.027827</td>
#             </tr>
#             <tr>
#                         <th id="T_e04ddfee_0452_11ec_9634_e454e890cb7dlevel0_row3" class="row_heading level0 row3" >STOK</th>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col0" class="data row3 col0" >0.058067</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col1" class="data row3 col1" >0.532161</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col2" class="data row3 col2" >0.608471</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow3_col4" class="data row3 col4" >0.315490</td>
#             </tr>
#             <tr>
#                         <th id="T_e04ddfee_0452_11ec_9634_e454e890cb7dlevel0_row4" class="row_heading level0 row4" >signal</th>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col0" class="data row4 col0" >-0.002424</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col1" class="data row4 col1" >-0.016279</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col2" class="data row4 col2" >0.027827</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col3" class="data row4 col3" >0.315490</td>
#                         <td id="T_e04ddfee_0452_11ec_9634_e454e890cb7drow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
#imputing
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
Database = my_imputer.fit_transform(Database)

# %%
#training set
u = pd.DataFrame(Database, columns = ['EMA_10', 'RSI_14D', 'MACD', 'STOK', 'signal'])
u[513:1109]
# Out:
#             EMA_10    RSI_14D         MACD       STOK  signal
# 513   39102.695790  74.568517  1200.587191  44.901579     1.0
# 514   39197.842010  70.695913  1169.297657  34.358784     1.0
# 515   39273.325281  70.975919  1130.420698  32.366091     1.0
# 516   39353.811593  65.949343  1095.295780  33.140133     3.0
# 517   39409.300395  69.692091  1050.747245  31.137532     1.0
# ...            ...        ...          ...        ...     ...
# 1104  22042.649094  55.032330   812.662779  53.372206     3.0
# 1105  22133.258350  51.061008   806.766896  37.120505     1.0
# 1106  22036.302286  47.340236   717.888162  14.915452     1.0
# 1107  22075.156416  50.308872   691.924616  29.364694     3.0
# 1108  22132.400704  50.834760   674.865718  30.324681     3.0
#
# [596 rows x 5 columns]

# %%
trial_test=u[364:513]#test set
X_test = trial_test[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_test = trial_test[['signal']]
#first = u[0:364]
trial_train = u[513:1109]#trainset
X_train = trial_train[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_train = trial_train[['signal']]
#trial_train=pd.concat([first, second], axis = 0)
#u.loc[row_indexer,column_indexer]

# %%
len(trial_train)
# Out:
# 596

# %%
from sklearn.metrics import precision_score,accuracy_score,roc_curve, f1_score,log_loss
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection

# %%
classifyers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    BaggingClassifier(),
    KNeighborsClassifier(),
    MLPClassifier()
    
]
models = []
for classifyer in classifyers:
    classifyer.fit(X_train,Y_train)
    print(f"{classifyer.__class__.__name__:10}: trained")
    models.append(classifyer)
# Out:
# DecisionTreeClassifier: trained
# RandomForestClassifier: trained
# BaggingClassifier: trained
# KNeighborsClassifier: trained
# MLPClassifier: trained
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/bagging.py:623: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
models
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=None, splitter='best'),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=10,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                    max_features=1.0, max_samples=1.0, n_estimators=10,
#                    n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                    warm_start=False),
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                hidden_layer_sizes=(100,), learning_rate='constant',
#                learning_rate_init=0.001, max_iter=200, momentum=0.9,
#                n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#                random_state=None, shuffle=True, solver='adam', tol=0.0001,
#                validation_fraction=0.1, verbose=False, warm_start=False)]

# %%
#classification report
from sklearn.metrics import classification_report
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: classification_report = {classification_report(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.56      0.61      0.58        79
#          3.0       0.51      0.46      0.48        70
#
#     accuracy                           0.54       149
#    macro avg       0.53      0.53      0.53       149
# weighted avg       0.53      0.54      0.53       149
#
#
# RandomForestClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.62      0.89      0.73        79
#          3.0       0.76      0.40      0.52        70
#
#     accuracy                           0.66       149
#    macro avg       0.69      0.64      0.63       149
# weighted avg       0.69      0.66      0.63       149
#
#
# BaggingClassifier     : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.62      0.72      0.67        79
#          3.0       0.61      0.50      0.55        70
#
#     accuracy                           0.62       149
#    macro avg       0.62      0.61      0.61       149
# weighted avg       0.62      0.62      0.61       149
#
#
# KNeighborsClassifier  : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.54      0.82      0.65        79
#          3.0       0.50      0.20      0.29        70
#
#     accuracy                           0.53       149
#    macro avg       0.52      0.51      0.47       149
# weighted avg       0.52      0.53      0.48       149
#
#
# MLPClassifier         : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        79
#          3.0       0.47      1.00      0.64        70
#
#     accuracy                           0.47       149
#    macro avg       0.23      0.50      0.32       149
# weighted avg       0.22      0.47      0.30       149
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: confusion_matrix(= {confusion_matrix(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: confusion_matrix(= [[48 31]
#  [38 32]]
#
# RandomForestClassifier: confusion_matrix(= [[70  9]
#  [42 28]]
#
# BaggingClassifier     : confusion_matrix(= [[57 22]
#  [35 35]]
#
# KNeighborsClassifier  : confusion_matrix(= [[65 14]
#  [56 14]]
#
# MLPClassifier         : confusion_matrix(= [[ 0 79]
#  [ 0 70]]

# %%
#auc score
from sklearn.metrics import roc_auc_score
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: roc_auc_score(= {roc_auc_score(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: roc_auc_score(= 0.5323688969258589
#
# RandomForestClassifier: roc_auc_score(= 0.6430379746835443
#
# BaggingClassifier     : roc_auc_score(= 0.6107594936708861
#
# KNeighborsClassifier  : roc_auc_score(= 0.5113924050632911
#
# MLPClassifier         : roc_auc_score(= 0.5

# %%
t2 = pd.DataFrame(Y_pred)
t2.value_counts()
# Out:
# 3.0    149
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read all data 
A = pd.read_html('Report16Jul2021120356.html')
#A

# %%
# choosing the data that we will use 
A1=A[11]
#A1

# %%
# changing the first row to be a header for all data
new_header1 = A1.iloc[0] #grab the first row for the header
A2 = A1[1:] #take the data less the header row
A2.columns = new_header1 #set the header row as the df header
A2 = A2.reset_index(drop=True)#reseting index
A2
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  12791  12380  12791  12431  6611403          0.00
# 1     14 Jul 2021  12852  12344  12501  12791  3836029          0.00
# 2     13 Jul 2021  13132  12434  13039  12523  4637130          0.00
# 3     12 Jul 2021  13276  12897  13200  13175  2990564          0.00
# 4     09 Jul 2021  13379  12902  12984  13321  4167265          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  13784  13544  13730  13739  4994159          0.00
# 1246  20 Jul 2016  13842  13377  13432  13675  7844545          0.00
# 1247  19 Jul 2016  13458  13163  13200  13458  2907433          0.00
# 1248  18 Jul 2016  13281  13011  13200  13281  2213537          0.00
# 1249  15 Jul 2016  13298  12765  12896  13258  3810403          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield     EY    P/E    DY
# 0                   0.00                   1.54   8.07  12.40  1.54
# 1                   0.00                   1.50   7.84  12.76  1.50
# 2                   0.00                   1.53   8.01  12.49  1.53
# 3                   0.00                   1.46   7.61  13.14  1.46
# 4                   0.00                   1.44   7.53  13.29  1.44
# ...                  ...                    ...    ...    ...   ...
# 1245                0.00                   4.17  10.11   9.89  4.17
# 1246                0.00                   4.19  10.16   9.85  4.19
# 1247                0.00                   4.26  10.32   9.69  4.26
# 1248                0.00                   4.31  10.46   9.56  4.31
# 1249                0.00                   4.32  10.48   9.55  4.32
#
# [1250 rows x 12 columns]

# %%
Indicator = A2.copy()#creating a copy
Indicator
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  12791  12380  12791  12431  6611403          0.00
# 1     14 Jul 2021  12852  12344  12501  12791  3836029          0.00
# 2     13 Jul 2021  13132  12434  13039  12523  4637130          0.00
# 3     12 Jul 2021  13276  12897  13200  13175  2990564          0.00
# 4     09 Jul 2021  13379  12902  12984  13321  4167265          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  13784  13544  13730  13739  4994159          0.00
# 1246  20 Jul 2016  13842  13377  13432  13675  7844545          0.00
# 1247  19 Jul 2016  13458  13163  13200  13458  2907433          0.00
# 1248  18 Jul 2016  13281  13011  13200  13281  2213537          0.00
# 1249  15 Jul 2016  13298  12765  12896  13258  3810403          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield     EY    P/E    DY
# 0                   0.00                   1.54   8.07  12.40  1.54
# 1                   0.00                   1.50   7.84  12.76  1.50
# 2                   0.00                   1.53   8.01  12.49  1.53
# 3                   0.00                   1.46   7.61  13.14  1.46
# 4                   0.00                   1.44   7.53  13.29  1.44
# ...                  ...                    ...    ...    ...   ...
# 1245                0.00                   4.17  10.11   9.89  4.17
# 1246                0.00                   4.19  10.16   9.85  4.19
# 1247                0.00                   4.26  10.32   9.69  4.26
# 1248                0.00                   4.31  10.46   9.56  4.31
# 1249                0.00                   4.32  10.48   9.55  4.32
#
# [1250 rows x 12 columns]

# %%
Indicator['Date'] = pd.to_datetime(Indicator.Date)#changing date fotmat
Indicator
# Out:
# 0          Date   High    Low   Open  Close   Volume InterestYield  \
# 0    2021-07-15  12791  12380  12791  12431  6611403          0.00
# 1    2021-07-14  12852  12344  12501  12791  3836029          0.00
# 2    2021-07-13  13132  12434  13039  12523  4637130          0.00
# 3    2021-07-12  13276  12897  13200  13175  2990564          0.00
# 4    2021-07-09  13379  12902  12984  13321  4167265          0.00
# ...         ...    ...    ...    ...    ...      ...           ...
# 1245 2016-07-21  13784  13544  13730  13739  4994159          0.00
# 1246 2016-07-20  13842  13377  13432  13675  7844545          0.00
# 1247 2016-07-19  13458  13163  13200  13458  2907433          0.00
# 1248 2016-07-18  13281  13011  13200  13281  2213537          0.00
# 1249 2016-07-15  13298  12765  12896  13258  3810403          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield     EY    P/E    DY
# 0                   0.00                   1.54   8.07  12.40  1.54
# 1                   0.00                   1.50   7.84  12.76  1.50
# 2                   0.00                   1.53   8.01  12.49  1.53
# 3                   0.00                   1.46   7.61  13.14  1.46
# 4                   0.00                   1.44   7.53  13.29  1.44
# ...                  ...                    ...    ...    ...   ...
# 1245                0.00                   4.17  10.11   9.89  4.17
# 1246                0.00                   4.19  10.16   9.85  4.19
# 1247                0.00                   4.26  10.32   9.69  4.26
# 1248                0.00                   4.31  10.46   9.56  4.31
# 1249                0.00                   4.32  10.48   9.55  4.32
#
# [1250 rows x 12 columns]

# %%
#changing data type to float
Indicator['High']=Indicator.High.astype('float')
Indicator['Close']=Indicator.Close.astype('float')
Indicator['Low']=Indicator.Low.astype('float')
Indicator['Open']=Indicator.Open.astype('float')

# %%
#deleting columns not used
del Indicator['Volume'],Indicator['TotalDistributionYield'], Indicator['InterestYield'], Indicator['CapitalPaymentYield'], Indicator['EY'], Indicator['DY'], Indicator['P/E']
#Indicator

# %%
Indicator.describe()#descriptive statistics
# Out:
# 0              High           Low          Open        Close
# count   1250.000000   1250.000000   1250.000000   1250.00000
# mean   16025.782400  15551.983200  15786.042400  15794.56240
# std     3218.911259   3193.000663   3204.240074   3204.81706
# min     8863.000000   8341.000000   8635.000000   8441.00000
# 25%    13724.250000  13303.250000  13512.000000  13539.75000
# 50%    16200.500000  15845.000000  16020.000000  16048.00000
# 75%    18599.250000  18042.000000  18268.750000  18372.50000
# max    23100.000000  22568.000000  22900.000000  22741.00000

# %%
Indicator['Direct'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #generating target variable
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct
# 0    2021-07-15  12791.0  12380.0  12791.0  12431.0     NaN
# 1    2021-07-14  12852.0  12344.0  12501.0  12791.0   360.0
# 2    2021-07-13  13132.0  12434.0  13039.0  12523.0  -268.0
# 3    2021-07-12  13276.0  12897.0  13200.0  13175.0   652.0
# 4    2021-07-09  13379.0  12902.0  12984.0  13321.0   146.0
# ...         ...      ...      ...      ...      ...     ...
# 1245 2016-07-21  13784.0  13544.0  13730.0  13739.0    49.0
# 1246 2016-07-20  13842.0  13377.0  13432.0  13675.0   -64.0
# 1247 2016-07-19  13458.0  13163.0  13200.0  13458.0  -217.0
# 1248 2016-07-18  13281.0  13011.0  13200.0  13281.0  -177.0
# 1249 2016-07-15  13298.0  12765.0  12896.0  13258.0   -23.0
#
# [1250 rows x 6 columns]

# %%
sig = []
for h in range (len(Indicator)):
    if Indicator['Direct'][h] > 0:#sell
        sig.append(3)
    else:
        sig.append(1)#buy
    
Indicator['signal'] = sig
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal
# 0    2021-07-15  12791.0  12380.0  12791.0  12431.0     NaN       1
# 1    2021-07-14  12852.0  12344.0  12501.0  12791.0   360.0       3
# 2    2021-07-13  13132.0  12434.0  13039.0  12523.0  -268.0       1
# 3    2021-07-12  13276.0  12897.0  13200.0  13175.0   652.0       3
# 4    2021-07-09  13379.0  12902.0  12984.0  13321.0   146.0       3
# ...         ...      ...      ...      ...      ...     ...     ...
# 1245 2016-07-21  13784.0  13544.0  13730.0  13739.0    49.0       3
# 1246 2016-07-20  13842.0  13377.0  13432.0  13675.0   -64.0       1
# 1247 2016-07-19  13458.0  13163.0  13200.0  13458.0  -217.0       1
# 1248 2016-07-18  13281.0  13011.0  13200.0  13281.0  -177.0       1
# 1249 2016-07-15  13298.0  12765.0  12896.0  13258.0   -23.0       1
#
# [1250 rows x 7 columns]

# %%
def RSI(value):
    '''
    The function calculates the relative strength index parameters 
    to be used to calculate 14_day rsi values
    '''
    up = value[value>0].mean()
    down = -value[value<0].mean()
    return (100 * up / (up + down))

Indicator['Direction'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #adding momentum
Indicator['RSI_14D'] = Indicator['Direction'].rolling(center=False, window=14).apply(RSI) #14D RSI

# %%
#Indicator['RSI_14D']

# %%
l = []
for i in range (len(Indicator)):
    if Indicator['RSI_14D'][i] >= 28 and Indicator['RSI_14D'][i] <= 30: # values below the signal line of 30 oversold
        l.append(1) #buy
    elif Indicator['RSI_14D'][i] >= 31 and Indicator['RSI_14D'][i] <= 69:
        l.append(2) #hold
    elif Indicator['RSI_14D'][i] >= 70:
        l.append(3)#sell
    else:
        l.append(2) #hold signal
Indicator['RSI_sig'] = l

# %%
sns.countplot(x = 'RSI_sig', data=pd.DataFrame(Indicator), hue='RSI_sig')
#plt.savefig("aspen_rsicount")
plt.show()
Indicator['RSI_sig'].value_counts() #counts according to signal code
# Out:
# 2    1198
# 3      32
# 1      20
# Name: RSI_sig, dtype: int64

# %%
r = Indicator['RSI_14D']
h = [0,1300]
b = [30,30]
f = plt.plot(r, label = 'RSI_14D')
e = [70,70]
g = plt.plot(h,b,h,e) + f
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_rsi")
plt.show(g)

# %%
n=21
Indicator['STOK'] = ((Indicator['Close'] - Indicator['Low'].rolling(window=n,center=False).mean()) /
                     (Indicator['High'].rolling(window=n, center=False).max() - 
                      Indicator['Low'].rolling(window=n, center=False).min())) * 100 #D% stochastic
Indicator['STOD'] = Indicator['STOK'].rolling(window = 7, center=False).mean()  #K% stochastic

# %%
m = []
for i in range (len(Indicator)):
    if Indicator['STOK'][i] >= 28 and Indicator['STOK'][i]<=30:
        m.append(1) #buy
    elif Indicator['STOK'][i] > 30 and Indicator['STOK'][i] <= 69:
        m.append(2) #sell    
    elif Indicator['STOK'][i] >= 70:
        m.append(3) #sell
    else:
        m.append(2) #hold
Indicator['STO_sig'] = m

# %%
sns.countplot(x = 'STO_sig', data=pd.DataFrame(Indicator), hue='STO_sig')
#plt.savefig("aspen_stocount")
plt.show()
Indicator['STO_sig'].value_counts()
# Out:
# 2    1226
# 1      22
# 3       2
# Name: STO_sig, dtype: int64

# %%
t = Indicator['STOD']
j = Indicator['STOK']
u = plt.plot(t, label = 'STOD')
s = plt.plot(j, label = 'STOK')
h = [0,1300]
b = [30,30]
e = [70,70]
g = plt.plot(h,e,h,b) + u + s
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_sto")
plt.show()

# %%
Indicator['EMA_10'] = Indicator['Close'].ewm(span=10,adjust=False,min_periods=1).mean() #50day exponential ma
Indicator['EMA_30'] = Indicator['Close'].ewm(span=20,adjust=False,min_periods=1).mean() #100day exponential ma
Indicator['EMA_90'] = Indicator['Close'].ewm(span=90,adjust=False,min_periods=1).mean() #200day exponential ma

# %%
# append 1 for a buy, 0 for a sell and 2 for hold and NaN
n = []
for i in range (len(Indicator)):
    if Indicator['EMA_10'][i] < Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(1) #buy
    elif Indicator['EMA_10'][i] > Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(3) #sell
    elif Indicator['EMA_10'][i] == Indicator['EMA_30'][i] == Indicator['EMA_90'][i]:
        n.append(2)  #hold      
    else:
        n.append(2)#hold
Indicator['EMA_sig'] = n

# %%
sns.countplot(x = 'EMA_sig', data=pd.DataFrame(Indicator), hue='EMA_sig')
#plt.savefig("aspen_emacount")
plt.show()
Indicator['EMA_sig'].value_counts()
# Out:
# 1    634
# 3    615
# 2      1
# Name: EMA_sig, dtype: int64

# %%
# buy if 50EMA line cuts the other two EMA lines from above and moves below both the EMAs
# sell if 50EMA line cuts the other two EMA lines from below and moves above both the EMAs
a = Indicator['EMA_10'] #50 day exponential moving average
b = Indicator['EMA_30'] #100 day exponential moving average
c = Indicator['EMA_90'] #200 day exponential moving average
d = plt.plot(a, label = 'EMA_10' ) + plt.plot(b, label = 'EMA_30') + plt.plot(c, label = 'EMA_90')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_ema")
plt.show(d)

# %%
Indicator['26_ema'] = Indicator['Close'].ewm(span=26,adjust=True,ignore_na=False).mean() #26day ema
Indicator['12_ema'] = Indicator['Close'].ewm(span=12,adjust=True,ignore_na=False).mean() #12day ema
Indicator['MACD'] = Indicator['12_ema'] - Indicator['26_ema'] #macd
Indicator['9EMA_MACD'] = Indicator['MACD'].ewm(span=9,adjust=True,ignore_na=False).mean() #9daymacd_ema
#Indicator

# %%
f = []
for i in range (len(Indicator)):
    if Indicator['MACD'][i] > Indicator['9EMA_MACD'][i]:
        f.append(1) #buy
    elif Indicator['MACD'][i] < Indicator['9EMA_MACD'][i]:
        f.append(3) #sell
    elif Indicator['MACD'][i] == Indicator['9EMA_MACD'][i]:
        f.append(2) #
    else:
        f.append(2)
Indicator['MACD_sig'] = f

# %%
sns.countplot(x = 'MACD_sig', data=pd.DataFrame(Indicator), hue='MACD_sig')
#plt.savefig("aspen_macdcount")
plt.show()
Indicator['MACD_sig'].value_counts()
# Out:
# 3    671
# 1    578
# 2      1
# Name: MACD_sig, dtype: int64

# %%
q = Indicator['9EMA_MACD']
e = Indicator['MACD']
z = [0,1300]
x = [0,0]
r = plt.plot(z,x)+ plt.plot(e, label = 'MACD') +plt.plot(q, label = '9EMA_MACD')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_macd")
plt.show(r)

# %%
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 0    2021-07-15  12791.0  12380.0  12791.0  12431.0     NaN       1
# 1    2021-07-14  12852.0  12344.0  12501.0  12791.0   360.0       3
# 2    2021-07-13  13132.0  12434.0  13039.0  12523.0  -268.0       1
# 3    2021-07-12  13276.0  12897.0  13200.0  13175.0   652.0       3
# 4    2021-07-09  13379.0  12902.0  12984.0  13321.0   146.0       3
# ...         ...      ...      ...      ...      ...     ...     ...
# 1245 2016-07-21  13784.0  13544.0  13730.0  13739.0    49.0       3
# 1246 2016-07-20  13842.0  13377.0  13432.0  13675.0   -64.0       1
# 1247 2016-07-19  13458.0  13163.0  13200.0  13458.0  -217.0       1
# 1248 2016-07-18  13281.0  13011.0  13200.0  13281.0  -177.0       1
# 1249 2016-07-15  13298.0  12765.0  12896.0  13258.0   -23.0       1
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 0           NaN        NaN        2  ...        2  12431.000000  12431.000000
# 1         360.0        NaN        2  ...        2  12496.454545  12465.285714
# 2        -268.0        NaN        2  ...        2  12501.280992  12470.782313
# 3         652.0        NaN        2  ...        2  12623.775357  12537.850664
# 4         146.0        NaN        2  ...        2  12750.543474  12612.436315
# ...         ...        ...      ...  ...      ...           ...           ...
# 1245       49.0  45.253863        2  ...        2  13986.192668  14148.172564
# 1246      -64.0  46.287688        2  ...        2  13929.612183  14103.108510
# 1247     -217.0  51.212958        2  ...        2  13843.864513  14041.669604
# 1248     -177.0  51.914298        2  ...        2  13741.525511  13969.224880
# 1249      -23.0  55.624803        2  ...        2  13653.611782  13901.489177
#
# 0           EMA_90  EMA_sig        26_ema        12_ema        MACD  \
# 0     12431.000000        2  12431.000000  12431.000000    0.000000
# 1     12438.912088        3  12617.923077  12626.000000    8.076923
# 2     12440.760174        3  12583.818137  12585.799076    1.980939
# 3     12456.897313        3  12749.086752  12771.786782   22.700030
# 4     12475.888581        3  12881.715793  12921.006050   39.290257
# ...            ...      ...           ...           ...         ...
# 1245  14322.742697        1  14178.379901  14037.239045 -141.140856
# 1246  14308.506594        1  14141.092501  13981.509961 -159.582540
# 1247  14289.814141        1  14090.493056  13900.969967 -189.523089
# 1248  14267.642402        1  14030.530608  13805.589972 -224.940636
# 1249  14245.452459        1  13973.306118  13721.345361 -251.960757
#
# 0      9EMA_MACD  MACD_sig
# 0       0.000000         2
# 1       4.487179         1
# 2       3.460032         3
# 3       9.977646         1
# 4      18.697485         1
# ...          ...       ...
# 1245  -30.177903         3
# 1246  -56.058830         3
# 1247  -82.751682         3
# 1248 -111.189473         3
# 1249 -139.343730         3
#
# [1250 rows x 22 columns]

# %%
start = Indicator[Indicator['Date']=='2020-01-31'].index[0]
end = Indicator[Indicator['Date']=='2017-02-07'].index[0]

#Show the sliced df (from 2017-01-07 to 2017-01-14)
Indicator.loc[start:end]
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 364  2020-01-31  16198.0  15748.0  16115.0  15748.0   -89.0       1
# 365  2020-01-30  16273.0  15802.0  16120.0  16162.0   414.0       3
# 366  2020-01-29  16204.0  16007.0  16015.0  16121.0   -41.0       1
# 367  2020-01-28  16137.0  15803.0  16137.0  15990.0  -131.0       1
# 368  2020-01-27  16300.0  15809.0  16300.0  15965.0   -25.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1104 2017-02-13  14662.0  14410.0  14452.0  14662.0   -86.0       1
# 1105 2017-02-10  14496.0  14200.0  14200.0  14452.0  -210.0       1
# 1106 2017-02-09  14179.0  13958.0  14000.0  14107.0  -345.0       1
# 1107 2017-02-08  14231.0  13823.0  14100.0  14019.0   -88.0       1
# 1108 2017-02-07  14130.0  13903.0  14033.0  14102.0    83.0       3
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 364       -89.0  54.343808        2  ...        2  16227.288113  15896.478065
# 365       414.0  51.663405        2  ...        2  16215.417547  15921.765868
# 366       -41.0  51.212415        2  ...        2  16198.250720  15940.740547
# 367      -131.0  50.206022        2  ...        2  16160.386953  15945.431924
# 368       -25.0  50.704225        2  ...        2  16124.862052  15947.295550
# ...         ...        ...      ...  ...      ...           ...           ...
# 1104      -86.0  20.903955        2  ...        2  14718.410270  14844.104463
# 1105     -210.0  20.376319        2  ...        2  14669.972039  14806.761181
# 1106     -345.0  28.334397        1  ...        2  14567.613487  14740.117259
# 1107      -88.0  33.183857        2  ...        2  14467.865580  14671.439425
# 1108       83.0  34.252620        2  ...        2  14401.344565  14617.207099
#
# 0           EMA_90  EMA_sig        26_ema        12_ema        MACD  \
# 364   13068.499302        3  15553.901600  16207.519714  653.618115
# 365   13136.488329        3  15598.945926  16200.516681  601.570756
# 366   13202.081992        3  15637.616598  16188.283346  550.666748
# 367   13263.354915        3  15663.719072  16157.778216  494.059144
# 368   13322.731730        3  15686.036178  16128.120029  442.083851
# ...            ...      ...           ...           ...         ...
# 1104  15042.492067        1  14885.895030  14744.636421 -141.258609
# 1105  15029.514219        1  14853.754657  14699.615433 -154.139224
# 1106  15009.239181        1  14798.439497  14608.443828 -189.995669
# 1107  14987.475683        1  14740.703238  14517.760162 -222.943076
# 1108  14968.014679        1  14693.391887  14453.797060 -239.594827
#
# 0      9EMA_MACD  MACD_sig
# 364   925.592389         3
# 365   860.788062         3
# 366   798.763800         3
# 367   737.822868         3
# 368   678.675065         3
# ...          ...       ...
# 1104 -126.707189         3
# 1105 -132.193596         3
# 1106 -143.754010         3
# 1107 -159.591824         3
# 1108 -175.592424         3
#
# [745 rows x 22 columns]

# %% [markdown]
# # Machine Learning

# %%
Database = Indicator[['EMA_10', 'RSI_14D', 'MACD', 'STOK','signal']]
Database
# Out:
# 0           EMA_10    RSI_14D        MACD       STOK  signal
# 0     12431.000000        NaN    0.000000        NaN       1
# 1     12496.454545        NaN    8.076923        NaN       3
# 2     12501.280992        NaN    1.980939        NaN       1
# 3     12623.775357        NaN   22.700030        NaN       3
# 4     12750.543474        NaN   39.290257        NaN       3
# ...            ...        ...         ...        ...     ...
# 1245  13986.192668  45.253863 -141.140856 -25.047360       3
# 1246  13929.612183  46.287688 -159.582540 -22.979402       1
# 1247  13843.864513  51.212958 -189.523089 -27.322933       1
# 1248  13741.525511  51.914298 -224.940636 -31.119120       1
# 1249  13653.611782  55.624803 -251.960757 -26.213865       1
#
# [1250 rows x 5 columns]

# %%
#correlation
g = Database.corr()
g.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
# #T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col0,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col1,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col2,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col3,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col4{
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col1,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col0{
#             background-color:  #2369ad;
#             color:  #f1f1f1;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col2{
#             background-color:  #3885bc;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col3,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col4,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col4,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col0,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col1,#T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col2{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col2{
#             background-color:  #f9f0eb;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col3{
#             background-color:  #fae8de;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col0{
#             background-color:  #3f8ec0;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col1{
#             background-color:  #f9ede5;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col3{
#             background-color:  #fae7dc;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col4{
#             background-color:  #0a3b70;
#             color:  #f1f1f1;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col0{
#             background-color:  #195696;
#             color:  #f1f1f1;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col1{
#             background-color:  #fcdfcf;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col2{
#             background-color:  #fce0d0;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col4{
#             background-color:  #96c7df;
#             color:  #000000;
#         }#T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col3{
#             background-color:  #6bacd1;
#             color:  #000000;
#         }</style><table id="T_d793c6e4_0451_11ec_9634_e454e890cb7d" ><thead>    <tr>        <th class="index_name level0" >0</th>        <th class="col_heading level0 col0" >EMA_10</th>        <th class="col_heading level0 col1" >RSI_14D</th>        <th class="col_heading level0 col2" >MACD</th>        <th class="col_heading level0 col3" >STOK</th>        <th class="col_heading level0 col4" >signal</th>    </tr>    <tr>        <th class="index_name level0" >0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d793c6e4_0451_11ec_9634_e454e890cb7dlevel0_row0" class="row_heading level0 row0" >EMA_10</th>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col1" class="data row0 col1" >0.092682</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col2" class="data row0 col2" >0.175624</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col3" class="data row0 col3" >0.058497</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow0_col4" class="data row0 col4" >-0.016246</td>
#             </tr>
#             <tr>
#                         <th id="T_d793c6e4_0451_11ec_9634_e454e890cb7dlevel0_row1" class="row_heading level0 row1" >RSI_14D</th>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col0" class="data row1 col0" >0.092682</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col2" class="data row1 col2" >0.529658</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col3" class="data row1 col3" >0.578150</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow1_col4" class="data row1 col4" >-0.017293</td>
#             </tr>
#             <tr>
#                         <th id="T_d793c6e4_0451_11ec_9634_e454e890cb7dlevel0_row2" class="row_heading level0 row2" >MACD</th>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col0" class="data row2 col0" >0.175624</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col1" class="data row2 col1" >0.529658</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col3" class="data row2 col3" >0.582939</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow2_col4" class="data row2 col4" >0.006185</td>
#             </tr>
#             <tr>
#                         <th id="T_d793c6e4_0451_11ec_9634_e454e890cb7dlevel0_row3" class="row_heading level0 row3" >STOK</th>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col0" class="data row3 col0" >0.058497</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col1" class="data row3 col1" >0.578150</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col2" class="data row3 col2" >0.582939</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow3_col4" class="data row3 col4" >0.296204</td>
#             </tr>
#             <tr>
#                         <th id="T_d793c6e4_0451_11ec_9634_e454e890cb7dlevel0_row4" class="row_heading level0 row4" >signal</th>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col0" class="data row4 col0" >-0.016246</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col1" class="data row4 col1" >-0.017293</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col2" class="data row4 col2" >0.006185</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col3" class="data row4 col3" >0.296204</td>
#                         <td id="T_d793c6e4_0451_11ec_9634_e454e890cb7drow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
#imputing values
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
Database = my_imputer.fit_transform(Database)

# %%
u = pd.DataFrame(Database, columns = ['EMA_10', 'RSI_14D', 'MACD', 'STOK', 'signal'])
u[513:1109]
# Out:
#             EMA_10    RSI_14D        MACD       STOK  signal
# 513   19260.798114  54.477531  383.851201  41.051478     1.0
# 514   19362.653003  54.536248  405.293594  43.903971     3.0
# 515   19514.897911  54.576836  447.708077  63.135338     3.0
# 516   19622.189200  65.824420  468.258364  55.812030     1.0
# 517   19748.882073  68.209135  496.093963  54.201681     3.0
# ...            ...        ...         ...        ...     ...
# 1104  14718.410270  20.903955 -141.258609  -2.777334     1.0
# 1105  14669.972039  20.376319 -154.139224 -11.173184     1.0
# 1106  14567.613487  28.334397 -189.995669 -24.362116     1.0
# 1107  14467.865580  33.183857 -222.943076 -24.227906     1.0
# 1108  14401.344565  34.252620 -239.594827 -16.939964     3.0
#
# [596 rows x 5 columns]

# %%
trial_test=u[364:513]#testset
X_test = trial_test[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_test = trial_test[['signal']]
#first = u[0:364]
trial_train = u[513:1109]#trainingset
X_train = trial_train[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_train = trial_train[['signal']]
#trial_train=pd.concat([first, second], axis = 0)
#u.loc[row_indexer,column_indexer]

# %%
trial_test["signal"].value_counts()
# Out:
# 3.0    83
# 1.0    66
# Name: signal, dtype: int64

# %%
from sklearn.metrics import precision_score,accuracy_score,roc_curve, f1_score,log_loss
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection

# %%
classifyers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    BaggingClassifier(),
    KNeighborsClassifier(),
    MLPClassifier()
    
]
models = []
for classifyer in classifyers:
    classifyer.fit(X_train,Y_train)
    print(f"{classifyer.__class__.__name__:10}: trained")
    models.append(classifyer)
# Out:
# DecisionTreeClassifier: trained
# RandomForestClassifier: trained
# BaggingClassifier: trained
# KNeighborsClassifier: trained
# MLPClassifier: trained
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/bagging.py:623: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
models
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=None, splitter='best'),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=10,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                    max_features=1.0, max_samples=1.0, n_estimators=10,
#                    n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                    warm_start=False),
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                hidden_layer_sizes=(100,), learning_rate='constant',
#                learning_rate_init=0.001, max_iter=200, momentum=0.9,
#                n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#                random_state=None, shuffle=True, solver='adam', tol=0.0001,
#                validation_fraction=0.1, verbose=False, warm_start=False)]

# %%
#classification report
from sklearn.metrics import classification_report
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: classification_report = {classification_report(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.45      0.50      0.47        66
#          3.0       0.57      0.52      0.54        83
#
#     accuracy                           0.51       149
#    macro avg       0.51      0.51      0.51       149
# weighted avg       0.52      0.51      0.51       149
#
#
# RandomForestClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.54      0.74      0.62        66
#          3.0       0.71      0.49      0.58        83
#
#     accuracy                           0.60       149
#    macro avg       0.62      0.62      0.60       149
# weighted avg       0.63      0.60      0.60       149
#
#
# BaggingClassifier     : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.54      0.67      0.59        66
#          3.0       0.67      0.54      0.60        83
#
#     accuracy                           0.60       149
#    macro avg       0.60      0.60      0.60       149
# weighted avg       0.61      0.60      0.60       149
#
#
# KNeighborsClassifier  : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.35      0.38      0.36        66
#          3.0       0.47      0.45      0.46        83
#
#     accuracy                           0.42       149
#    macro avg       0.41      0.41      0.41       149
# weighted avg       0.42      0.42      0.42       149
#
#
# MLPClassifier         : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.73      0.24      0.36        66
#          3.0       0.61      0.93      0.73        83
#
#     accuracy                           0.62       149
#    macro avg       0.67      0.59      0.55       149
# weighted avg       0.66      0.62      0.57       149

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: confusion_matrix(= {confusion_matrix(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: confusion_matrix(= [[33 33]
#  [40 43]]
#
# RandomForestClassifier: confusion_matrix(= [[49 17]
#  [42 41]]
#
# BaggingClassifier     : confusion_matrix(= [[44 22]
#  [38 45]]
#
# KNeighborsClassifier  : confusion_matrix(= [[25 41]
#  [46 37]]
#
# MLPClassifier         : confusion_matrix(= [[16 50]
#  [ 6 77]]

# %%
#roc_auc score
from sklearn.metrics import roc_auc_score
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: roc_auc_score(= {roc_auc_score(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: roc_auc_score(= 0.5090361445783133
#
# RandomForestClassifier: roc_auc_score(= 0.6182000730193501
#
# BaggingClassifier     : roc_auc_score(= 0.604417670682731
#
# KNeighborsClassifier  : roc_auc_score(= 0.4122855056589997
#
# MLPClassifier         : roc_auc_score(= 0.5850675428988682

# %%
t2 = pd.DataFrame(Y_pred)
t2.value_counts()
# Out:
# 3.0    133
# 1.0     16
# dtype: int64

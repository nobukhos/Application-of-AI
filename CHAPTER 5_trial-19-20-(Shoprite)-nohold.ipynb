# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read all data 
A = pd.read_html('Report16Jul2021121824.html')
#A

# %%
# choosing the data that we will use 
A1=A[11]
#A1

# %%
# changing the first row to be a header for all data
new_header1 = A1.iloc[0] #grab the first row for the header
A2 = A1[1:] #take the data less the header row
A2.columns = new_header1 #set the header row as the df header
A2 = A2.reset_index(drop=True)#reset index
A2
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  15803  15480  15480  15570   754753          0.00
# 1     14 Jul 2021  15619  15182  15300  15500  1954919          0.00
# 2     13 Jul 2021  15928  15283  15818  15308  1977643          0.00
# 3     12 Jul 2021  15964  15539  15670  15964  1281776          0.00
# 4     09 Jul 2021  16250  15700  16000  15787  1216439          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  19484  18713  19375  19258  2873539          0.00
# 1246  20 Jul 2016  19498  17800  17800  19498  6970302          0.00
# 1247  19 Jul 2016  17836  17170  17515  17511  2072274          0.00
# 1248  18 Jul 2016  17688  17009  17483  17676  1185399          0.00
# 1249  15 Jul 2016  17578  16945  17000  17515  1183251          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.15  5.16  19.37  2.15
# 1                   0.00                   2.16  5.19  19.29  2.16
# 2                   0.00                   2.18  5.25  19.05  2.18
# 3                   0.00                   2.09  5.03  19.86  2.09
# 4                   0.00                   2.12  5.09  19.64  2.12
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   1.76  4.19  23.89  1.76
# 1246                0.00                   1.74  4.13  24.19  1.74
# 1247                0.00                   1.94  4.60  21.73  1.94
# 1248                0.00                   1.92  4.56  21.93  1.92
# 1249                0.00                   1.94  4.60  21.73  1.94
#
# [1250 rows x 12 columns]

# %%
Indicator = A2.copy()#make a copy
Indicator
# Out:
# 0            Date   High    Low   Open  Close   Volume InterestYield  \
# 0     15 Jul 2021  15803  15480  15480  15570   754753          0.00
# 1     14 Jul 2021  15619  15182  15300  15500  1954919          0.00
# 2     13 Jul 2021  15928  15283  15818  15308  1977643          0.00
# 3     12 Jul 2021  15964  15539  15670  15964  1281776          0.00
# 4     09 Jul 2021  16250  15700  16000  15787  1216439          0.00
# ...           ...    ...    ...    ...    ...      ...           ...
# 1245  21 Jul 2016  19484  18713  19375  19258  2873539          0.00
# 1246  20 Jul 2016  19498  17800  17800  19498  6970302          0.00
# 1247  19 Jul 2016  17836  17170  17515  17511  2072274          0.00
# 1248  18 Jul 2016  17688  17009  17483  17676  1185399          0.00
# 1249  15 Jul 2016  17578  16945  17000  17515  1183251          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.15  5.16  19.37  2.15
# 1                   0.00                   2.16  5.19  19.29  2.16
# 2                   0.00                   2.18  5.25  19.05  2.18
# 3                   0.00                   2.09  5.03  19.86  2.09
# 4                   0.00                   2.12  5.09  19.64  2.12
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   1.76  4.19  23.89  1.76
# 1246                0.00                   1.74  4.13  24.19  1.74
# 1247                0.00                   1.94  4.60  21.73  1.94
# 1248                0.00                   1.92  4.56  21.93  1.92
# 1249                0.00                   1.94  4.60  21.73  1.94
#
# [1250 rows x 12 columns]

# %%
Indicator['Date'] = pd.to_datetime(Indicator.Date)#changing dTE FORMAT
Indicator
# Out:
# 0          Date   High    Low   Open  Close   Volume InterestYield  \
# 0    2021-07-15  15803  15480  15480  15570   754753          0.00
# 1    2021-07-14  15619  15182  15300  15500  1954919          0.00
# 2    2021-07-13  15928  15283  15818  15308  1977643          0.00
# 3    2021-07-12  15964  15539  15670  15964  1281776          0.00
# 4    2021-07-09  16250  15700  16000  15787  1216439          0.00
# ...         ...    ...    ...    ...    ...      ...           ...
# 1245 2016-07-21  19484  18713  19375  19258  2873539          0.00
# 1246 2016-07-20  19498  17800  17800  19498  6970302          0.00
# 1247 2016-07-19  17836  17170  17515  17511  2072274          0.00
# 1248 2016-07-18  17688  17009  17483  17676  1185399          0.00
# 1249 2016-07-15  17578  16945  17000  17515  1183251          0.00
#
# 0    CapitalPaymentYield TotalDistributionYield    EY    P/E    DY
# 0                   0.00                   2.15  5.16  19.37  2.15
# 1                   0.00                   2.16  5.19  19.29  2.16
# 2                   0.00                   2.18  5.25  19.05  2.18
# 3                   0.00                   2.09  5.03  19.86  2.09
# 4                   0.00                   2.12  5.09  19.64  2.12
# ...                  ...                    ...   ...    ...   ...
# 1245                0.00                   1.76  4.19  23.89  1.76
# 1246                0.00                   1.74  4.13  24.19  1.74
# 1247                0.00                   1.94  4.60  21.73  1.94
# 1248                0.00                   1.92  4.56  21.93  1.92
# 1249                0.00                   1.94  4.60  21.73  1.94
#
# [1250 rows x 12 columns]

# %%
#CHANGING DATATYPE TO FLOAT
Indicator['High']=Indicator.High.astype('float')
Indicator['Close']=Indicator.Close.astype('float')
Indicator['Low']=Indicator.Low.astype('float')
Indicator['Open']=Indicator.Open.astype('float')

# %%
#Deleting unused columns
del Indicator['Volume'],Indicator['TotalDistributionYield'], Indicator['InterestYield'], Indicator['CapitalPaymentYield'], Indicator['EY'], Indicator['DY'], Indicator['P/E']
#Indicator

# %%
Indicator.describe()#descriptive statistics
# Out:
# 0              High           Low          Open         Close
# count   1250.000000   1250.000000   1250.000000   1250.000000
# mean   17492.672800  16955.044000  17231.846400  17222.808000
# std     4107.809877   4012.711805   4055.292362   4066.538297
# min    10155.000000   9501.000000   9727.000000  10028.000000
# 25%    13805.750000  13329.000000  13612.250000  13590.500000
# 50%    17785.500000  17222.500000  17500.000000  17516.500000
# 75%    20496.750000  20000.000000  20293.000000  20223.750000
# max    28190.000000  26810.000000  27840.000000  27550.000000

# %%
Indicator['Direct'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #target variable generation
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct
# 0    2021-07-15  15803.0  15480.0  15480.0  15570.0     NaN
# 1    2021-07-14  15619.0  15182.0  15300.0  15500.0   -70.0
# 2    2021-07-13  15928.0  15283.0  15818.0  15308.0  -192.0
# 3    2021-07-12  15964.0  15539.0  15670.0  15964.0   656.0
# 4    2021-07-09  16250.0  15700.0  16000.0  15787.0  -177.0
# ...         ...      ...      ...      ...      ...     ...
# 1245 2016-07-21  19484.0  18713.0  19375.0  19258.0  -691.0
# 1246 2016-07-20  19498.0  17800.0  17800.0  19498.0   240.0
# 1247 2016-07-19  17836.0  17170.0  17515.0  17511.0 -1987.0
# 1248 2016-07-18  17688.0  17009.0  17483.0  17676.0   165.0
# 1249 2016-07-15  17578.0  16945.0  17000.0  17515.0  -161.0
#
# [1250 rows x 6 columns]

# %%
sig = []
for h in range (len(Indicator)):
    if Indicator['Direct'][h] > 0:
        sig.append(3)#sell
    else:
        sig.append(1)#buy
    
Indicator['signal'] = sig
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal
# 0    2021-07-15  15803.0  15480.0  15480.0  15570.0     NaN       1
# 1    2021-07-14  15619.0  15182.0  15300.0  15500.0   -70.0       1
# 2    2021-07-13  15928.0  15283.0  15818.0  15308.0  -192.0       1
# 3    2021-07-12  15964.0  15539.0  15670.0  15964.0   656.0       3
# 4    2021-07-09  16250.0  15700.0  16000.0  15787.0  -177.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1245 2016-07-21  19484.0  18713.0  19375.0  19258.0  -691.0       1
# 1246 2016-07-20  19498.0  17800.0  17800.0  19498.0   240.0       3
# 1247 2016-07-19  17836.0  17170.0  17515.0  17511.0 -1987.0       1
# 1248 2016-07-18  17688.0  17009.0  17483.0  17676.0   165.0       3
# 1249 2016-07-15  17578.0  16945.0  17000.0  17515.0  -161.0       1
#
# [1250 rows x 7 columns]

# %%
def RSI(value):
    '''
    The function calculates the relative strength index parameters 
    to be used to calculate 14_day rsi values
    '''
    up = value[value>0].mean()
    down = -value[value<0].mean()
    return (100 * up / (up + down))

Indicator['Direction'] = (Indicator['Close'] - Indicator['Close'].shift(1)) #adding momentum
Indicator['RSI_14D'] = Indicator['Direction'].rolling(center=False, window=14).apply(RSI) #14D RSI

# %%
#Indicator['RSI_14D']

# %%
l = []
for i in range (len(Indicator)):
    if Indicator['RSI_14D'][i] >= 28 and Indicator['RSI_14D'][i] <= 30: # values below the signal line of 30 oversold
        l.append(1) #buy
    elif Indicator['RSI_14D'][i] >= 31 and Indicator['RSI_14D'][i] <= 69:
        l.append(2) #hold
    elif Indicator['RSI_14D'][i] >= 70:
        l.append(3)#sell
    else:
        l.append(2) #hold signal
Indicator['RSI_sig'] = l

# %%
sns.countplot(x = 'RSI_sig', data=pd.DataFrame(Indicator), hue='RSI_sig')
#plt.savefig("aspen_rsicount")
plt.show()
Indicator['RSI_sig'].value_counts() #counts according to signal code
# Out:
# 2    1154
# 3      78
# 1      18
# Name: RSI_sig, dtype: int64

# %%
r = Indicator['RSI_14D']
h = [0,1300]
b = [30,30]
f = plt.plot(r, label = 'RSI_14D')
e = [70,70]
g = plt.plot(h,b,h,e) + f
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_rsi")
plt.show(g)

# %%
n=21
Indicator['STOK'] = ((Indicator['Close'] - Indicator['Low'].rolling(window=n,center=False).mean()) /
                     (Indicator['High'].rolling(window=n, center=False).max() - 
                      Indicator['Low'].rolling(window=n, center=False).min())) * 100 #D% stochastic
Indicator['STOD'] = Indicator['STOK'].rolling(window = 7, center=False).mean()  #K% stochastic

# %%
m = []
for i in range (len(Indicator)):
    if Indicator['STOK'][i] >= 28 and Indicator['STOK'][i]<=30:
        m.append(1) #buy
    elif Indicator['STOK'][i] > 30 and Indicator['STOK'][i] <= 69:
        m.append(2) #sell    
    elif Indicator['STOK'][i] >= 70:
        m.append(3) #sell
    else:
        m.append(2) #hold
Indicator['STO_sig'] = m

# %%
sns.countplot(x = 'STO_sig', data=pd.DataFrame(Indicator), hue='STO_sig')
#plt.savefig("aspen_stocount")
plt.show()
Indicator['STO_sig'].value_counts()
# Out:
# 2    1223
# 1      25
# 3       2
# Name: STO_sig, dtype: int64

# %%
t = Indicator['STOD']
j = Indicator['STOK']
u = plt.plot(t, label = 'STOD')
s = plt.plot(j, label = 'STOK')
h = [0,1300]
b = [30,30]
e = [70,70]
g = plt.plot(h,e,h,b) + u + s
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_sto")
plt.show()

# %%
Indicator['EMA_10'] = Indicator['Close'].ewm(span=10,adjust=False,min_periods=1).mean() #50day exponential ma
Indicator['EMA_30'] = Indicator['Close'].ewm(span=20,adjust=False,min_periods=1).mean() #100day exponential ma
Indicator['EMA_90'] = Indicator['Close'].ewm(span=90,adjust=False,min_periods=1).mean() #200day exponential ma

# %%
# append 1 for a buy, 0 for a sell and 2 for hold and NaN
n = []
for i in range (len(Indicator)):
    if Indicator['EMA_10'][i] < Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(1) #buy
    elif Indicator['EMA_10'][i] > Indicator['EMA_30'][i] and Indicator['EMA_90'][i]:
        n.append(3) #sell
    elif Indicator['EMA_10'][i] == Indicator['EMA_30'][i] == Indicator['EMA_90'][i]:
        n.append(2)  #hold      
    else:
        n.append(2)#hold
Indicator['EMA_sig'] = n

# %%
sns.countplot(x = 'EMA_sig', data=pd.DataFrame(Indicator), hue='EMA_sig')
#plt.savefig("aspen_emacount")
plt.show()
Indicator['EMA_sig'].value_counts()
# Out:
# 3    665
# 1    584
# 2      1
# Name: EMA_sig, dtype: int64

# %%
# buy if 50EMA line cuts the other two EMA lines from above and moves below both the EMAs
# sell if 50EMA line cuts the other two EMA lines from below and moves above both the EMAs
a = Indicator['EMA_10'] #50 day exponential moving average
b = Indicator['EMA_30'] #100 day exponential moving average
c = Indicator['EMA_90'] #200 day exponential moving average
d = plt.plot(a, label = 'EMA_10' ) + plt.plot(b, label = 'EMA_30') + plt.plot(c, label = 'EMA_90')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_ema")
plt.show(d)

# %%
Indicator['26_ema'] = Indicator['Close'].ewm(span=26,adjust=True,ignore_na=False).mean() #26day ema
Indicator['12_ema'] = Indicator['Close'].ewm(span=12,adjust=True,ignore_na=False).mean() #12day ema
Indicator['MACD'] = Indicator['12_ema'] - Indicator['26_ema'] #macd
Indicator['9EMA_MACD'] = Indicator['MACD'].ewm(span=9,adjust=True,ignore_na=False).mean() #9daymacd_ema
#Indicator

# %%
f = []
for i in range (len(Indicator)):
    if Indicator['MACD'][i] > Indicator['9EMA_MACD'][i]:
        f.append(1) #buy
    elif Indicator['MACD'][i] < Indicator['9EMA_MACD'][i]:
        f.append(3) #sell
    elif Indicator['MACD'][i] == Indicator['9EMA_MACD'][i]:
        f.append(2) #
    else:
        f.append(2)
Indicator['MACD_sig'] = f

# %%
sns.countplot(x = 'MACD_sig', data=pd.DataFrame(Indicator), hue='MACD_sig')
#plt.savefig("aspen_macdcount")
plt.show()
Indicator['MACD_sig'].value_counts()
# Out:
# 1    635
# 3    614
# 2      1
# Name: MACD_sig, dtype: int64

# %%
q = Indicator['9EMA_MACD']
e = Indicator['MACD']
z = [0,1300]
x = [0,0]
r = plt.plot(z,x)+ plt.plot(e, label = 'MACD') +plt.plot(q, label = '9EMA_MACD')
plt.ylabel('Threshold value')
plt.xlabel('Days')
plt.legend()
#plt.savefig("aspen_macd")
plt.show(r)

# %%
Indicator
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 0    2021-07-15  15803.0  15480.0  15480.0  15570.0     NaN       1
# 1    2021-07-14  15619.0  15182.0  15300.0  15500.0   -70.0       1
# 2    2021-07-13  15928.0  15283.0  15818.0  15308.0  -192.0       1
# 3    2021-07-12  15964.0  15539.0  15670.0  15964.0   656.0       3
# 4    2021-07-09  16250.0  15700.0  16000.0  15787.0  -177.0       1
# ...         ...      ...      ...      ...      ...     ...     ...
# 1245 2016-07-21  19484.0  18713.0  19375.0  19258.0  -691.0       1
# 1246 2016-07-20  19498.0  17800.0  17800.0  19498.0   240.0       3
# 1247 2016-07-19  17836.0  17170.0  17515.0  17511.0 -1987.0       1
# 1248 2016-07-18  17688.0  17009.0  17483.0  17676.0   165.0       3
# 1249 2016-07-15  17578.0  16945.0  17000.0  17515.0  -161.0       1
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 0           NaN        NaN        2  ...        2  15570.000000  15570.000000
# 1         -70.0        NaN        2  ...        2  15557.272727  15563.333333
# 2        -192.0        NaN        2  ...        2  15511.950413  15539.015873
# 3         656.0        NaN        2  ...        2  15594.141247  15579.490552
# 4        -177.0        NaN        2  ...        2  15629.206475  15599.253356
# ...         ...        ...      ...  ...      ...           ...           ...
# 1245     -691.0  31.755399        2  ...        2  19998.458840  20046.831794
# 1246      240.0  34.793926        2  ...        2  19907.466324  19994.562099
# 1247    -1987.0  23.338456        2  ...        2  19471.745174  19758.032376
# 1248      165.0  22.699635        2  ...        2  19145.246051  19559.743578
# 1249     -161.0  22.253129        2  ...        2  18848.837678  19365.006094
#
# 0           EMA_90  EMA_sig        26_ema        12_ema        MACD  \
# 0     15570.000000        2  15570.000000  15570.000000    0.000000
# 1     15568.461538        1  15533.653846  15532.083333   -1.570513
# 2     15562.737109        1  15452.578610  15444.623557   -7.955054
# 3     15571.556074        3  15595.549682  15608.570402   13.020720
# 4     15576.291105        3  15639.947800  15657.049086   17.101286
# ...            ...      ...           ...           ...         ...
# 1245  19418.034566        1  19989.874293  20036.531002   46.656709
# 1246  19419.792048        1  19953.439160  19953.680079    0.240919
# 1247  19377.840574        1  19772.517741  19577.883143 -194.634597
# 1248  19340.437485        1  19617.220130  19285.285737 -331.934394
# 1249  19300.317980        1  19461.500121  19012.934085 -448.566036
#
# 0      9EMA_MACD  MACD_sig
# 0       0.000000         2
# 1      -0.872507         3
# 2      -3.775190         3
# 3       1.914481         1
# 4       6.432212         1
# ...          ...       ...
# 1245  212.856174         3
# 1246  170.333123         3
# 1247   97.339579         3
# 1248   11.484784         3
# 1249  -80.525380         3
#
# [1250 rows x 22 columns]

# %%
start = Indicator[Indicator['Date']=='2020-01-31'].index[0]
end = Indicator[Indicator['Date']=='2017-02-07'].index[0]

#Show the sliced df (from 2017-01-07 to 2017-01-14)
Indicator.loc[start:end]
# Out:
# 0          Date     High      Low     Open    Close  Direct  signal  \
# 364  2020-01-31  11865.0  11691.0  11865.0  11706.0  -266.0       1
# 365  2020-01-30  11885.0  11522.0  11700.0  11865.0   159.0       3
# 366  2020-01-29  11950.0  11705.0  11950.0  11718.0  -147.0       1
# 367  2020-01-28  12125.0  11786.0  12125.0  11800.0    82.0       3
# 368  2020-01-27  12160.0  11940.0  12160.0  12054.0   254.0       3
# ...         ...      ...      ...      ...      ...     ...     ...
# 1104 2017-02-13  17874.0  17400.0  17417.0  17671.0   153.0       3
# 1105 2017-02-10  17501.0  17051.0  17135.0  17416.0  -255.0       1
# 1106 2017-02-09  17436.0  17000.0  17287.0  17000.0  -416.0       1
# 1107 2017-02-08  17330.0  17008.0  17330.0  17285.0   285.0       3
# 1108 2017-02-07  17392.0  17098.0  17371.0  17330.0    45.0       3
#
# 0     Direction    RSI_14D  RSI_sig  ...  STO_sig        EMA_10        EMA_30  \
# 364      -266.0  53.770417        2  ...        2  11792.947368  11653.879512
# 365       159.0  50.258684        2  ...        2  11806.047847  11673.986225
# 366      -147.0  50.000000        2  ...        2  11790.039147  11678.178013
# 367        82.0  46.103038        2  ...        2  11791.850212  11689.780107
# 368       254.0  51.467090        2  ...        2  11839.513809  11724.467716
# ...         ...        ...      ...  ...      ...           ...           ...
# 1104      153.0  37.252651        2  ...        2  18189.471687  18734.658941
# 1105     -255.0  37.282866        2  ...        2  18048.840471  18609.072375
# 1106     -416.0  37.766033        2  ...        2  17858.142204  18455.827387
# 1107      285.0  38.641748        2  ...        2  17753.934530  18344.320017
# 1108       45.0  34.059406        2  ...        2  17676.855525  18247.718111
#
# 0           EMA_90  EMA_sig        26_ema        12_ema        MACD  \
# 364   11480.436932        3  11612.718952  11755.042378  142.323426
# 365   11488.888868        3  11631.406437  11771.958935  140.552498
# 366   11493.924277        3  11637.820775  11763.657561  125.836786
# 367   11500.651216        3  11649.834051  11769.248705  119.414654
# 368   11512.812728        3  11679.772269  11813.056597  133.284327
# ...            ...      ...           ...           ...         ...
# 1104  19775.793961        1  18943.610869  18325.282659 -618.328210
# 1105  19723.930357        1  18830.454509  18185.393019 -645.061489
# 1106  19664.063756        1  18694.865286  18003.024863 -691.840423
# 1107  19611.776641        1  18590.430820  17892.559499 -697.871321
# 1108  19561.627704        1  18497.065574  17806.011884 -691.053690
#
# 0      9EMA_MACD  MACD_sig
# 364    81.193922         1
# 365    93.065638         1
# 366    99.619867         1
# 367   103.578825         1
# 368   109.519925         1
# ...          ...       ...
# 1104 -448.667394         3
# 1105 -487.946213         3
# 1106 -528.725055         3
# 1107 -562.554308         3
# 1108 -588.254184         3
#
# [745 rows x 22 columns]

# %% [markdown]
# # Machine Learning

# %%
Database = Indicator[['EMA_10', 'RSI_14D', 'MACD', 'STOK','signal']]
Database
# Out:
# 0           EMA_10    RSI_14D        MACD       STOK  signal
# 0     15570.000000        NaN    0.000000        NaN       1
# 1     15557.272727        NaN   -1.570513        NaN       1
# 2     15511.950413        NaN   -7.955054        NaN       1
# 3     15594.141247        NaN   13.020720        NaN       3
# 4     15629.206475        NaN   17.101286        NaN       1
# ...            ...        ...         ...        ...     ...
# 1245  19998.458840  31.755399   46.656709 -32.254510       1
# 1246  19907.466324  34.793926    0.240919 -13.594561       3
# 1247  19471.745174  23.338456 -194.634597 -57.633787       1
# 1248  19145.246051  22.699635 -331.934394 -47.697898       3
# 1249  18848.837678  22.253129 -448.566036 -47.192491       1
#
# [1250 rows x 5 columns]

# %%
#correlation
g = Database.corr()
g.style.background_gradient(cmap='RdBu_r')
# Out:
# <style  type="text/css" >
# #T_97656f68_0452_11ec_9634_e454e890cb7drow0_col0,#T_97656f68_0452_11ec_9634_e454e890cb7drow1_col1,#T_97656f68_0452_11ec_9634_e454e890cb7drow2_col2,#T_97656f68_0452_11ec_9634_e454e890cb7drow3_col3,#T_97656f68_0452_11ec_9634_e454e890cb7drow4_col4{
#             background-color:  #67001f;
#             color:  #f1f1f1;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow0_col1,#T_97656f68_0452_11ec_9634_e454e890cb7drow0_col2{
#             background-color:  #408fc1;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow0_col3,#T_97656f68_0452_11ec_9634_e454e890cb7drow1_col4,#T_97656f68_0452_11ec_9634_e454e890cb7drow4_col0,#T_97656f68_0452_11ec_9634_e454e890cb7drow4_col1,#T_97656f68_0452_11ec_9634_e454e890cb7drow4_col2{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow0_col4{
#             background-color:  #134c87;
#             color:  #f1f1f1;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow1_col0{
#             background-color:  #307ab6;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow1_col2{
#             background-color:  #fbe4d6;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow1_col3{
#             background-color:  #f7f5f4;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow2_col0{
#             background-color:  #4393c3;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow2_col1{
#             background-color:  #fddcc9;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow2_col3{
#             background-color:  #fddbc7;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow2_col4{
#             background-color:  #175290;
#             color:  #f1f1f1;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow3_col0{
#             background-color:  #2a71b2;
#             color:  #f1f1f1;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow3_col1{
#             background-color:  #fdddcb;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow3_col2{
#             background-color:  #f9c2a7;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow3_col4{
#             background-color:  #a2cde3;
#             color:  #000000;
#         }#T_97656f68_0452_11ec_9634_e454e890cb7drow4_col3{
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }</style><table id="T_97656f68_0452_11ec_9634_e454e890cb7d" ><thead>    <tr>        <th class="index_name level0" >0</th>        <th class="col_heading level0 col0" >EMA_10</th>        <th class="col_heading level0 col1" >RSI_14D</th>        <th class="col_heading level0 col2" >MACD</th>        <th class="col_heading level0 col3" >STOK</th>        <th class="col_heading level0 col4" >signal</th>    </tr>    <tr>        <th class="index_name level0" >0</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97656f68_0452_11ec_9634_e454e890cb7dlevel0_row0" class="row_heading level0 row0" >EMA_10</th>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow0_col1" class="data row0 col1" >0.108803</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow0_col2" class="data row0 col2" >0.164117</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow0_col3" class="data row0 col3" >0.086399</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow0_col4" class="data row0 col4" >-0.045642</td>
#             </tr>
#             <tr>
#                         <th id="T_97656f68_0452_11ec_9634_e454e890cb7dlevel0_row1" class="row_heading level0 row1" >RSI_14D</th>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow1_col0" class="data row1 col0" >0.108803</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow1_col2" class="data row1 col2" >0.554212</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow1_col3" class="data row1 col3" >0.549610</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow1_col4" class="data row1 col4" >-0.102946</td>
#             </tr>
#             <tr>
#                         <th id="T_97656f68_0452_11ec_9634_e454e890cb7dlevel0_row2" class="row_heading level0 row2" >MACD</th>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow2_col0" class="data row2 col0" >0.164117</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow2_col1" class="data row2 col1" >0.554212</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow2_col3" class="data row2 col3" >0.634415</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow2_col4" class="data row2 col4" >-0.033794</td>
#             </tr>
#             <tr>
#                         <th id="T_97656f68_0452_11ec_9634_e454e890cb7dlevel0_row3" class="row_heading level0 row3" >STOK</th>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow3_col0" class="data row3 col0" >0.086399</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow3_col1" class="data row3 col1" >0.549610</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow3_col2" class="data row3 col2" >0.634415</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow3_col4" class="data row3 col4" >0.257080</td>
#             </tr>
#             <tr>
#                         <th id="T_97656f68_0452_11ec_9634_e454e890cb7dlevel0_row4" class="row_heading level0 row4" >signal</th>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow4_col0" class="data row4 col0" >-0.045642</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow4_col1" class="data row4 col1" >-0.102946</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow4_col2" class="data row4 col2" >-0.033794</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow4_col3" class="data row4 col3" >0.257080</td>
#                         <td id="T_97656f68_0452_11ec_9634_e454e890cb7drow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
#imputation
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
Database = my_imputer.fit_transform(Database)

# %%
u = pd.DataFrame(Database, columns = ['EMA_10', 'RSI_14D', 'MACD', 'STOK', 'signal'])
u[513:1109]
# Out:
#             EMA_10    RSI_14D        MACD       STOK  signal
# 513   15702.780403  51.796289  319.356265  16.315286     1.0
# 514   15737.729421  53.330139  312.753566  22.462817     3.0
# 515   15794.869526  49.111808  316.540585  32.546737     3.0
# 516   15904.893249  55.263158  343.661006  55.012346     3.0
# 517   15990.367203  55.294791  358.998533  48.048346     1.0
# ...            ...        ...         ...        ...     ...
# 1104  18189.471687  37.252651 -618.328210 -33.763385     3.0
# 1105  18048.840471  37.282866 -645.061489 -37.761129     1.0
# 1106  17858.142204  37.766033 -691.840423 -47.572639     1.0
# 1107  17753.934530  38.641748 -697.871321 -33.671457     3.0
# 1108  17676.855525  34.059406 -691.053690 -28.188554     3.0
#
# [596 rows x 5 columns]

# %%
trial_test=u[364:513]#testset
X_test = trial_test[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_test = trial_test[['signal']]
#first = u[0:364]
trial_train = u[513:1109]#train set
X_train = trial_train[['EMA_10', 'RSI_14D', 'MACD', 'STOK']]
Y_train = trial_train[['signal']]
#trial_train=pd.concat([first, second], axis = 0)
#u.loc[row_indexer,column_indexer]

# %%
len(trial_train)
# Out:
# 596

# %%
from sklearn.metrics import precision_score,accuracy_score,roc_curve, f1_score,log_loss
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection

# %%
classifyers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    BaggingClassifier(),
    KNeighborsClassifier(),
    MLPClassifier()
    
]
models = []
for classifyer in classifyers:
    classifyer.fit(X_train,Y_train)
    print(f"{classifyer.__class__.__name__:10}: trained")
    models.append(classifyer)
# Out:
# DecisionTreeClassifier: trained
# RandomForestClassifier: trained
# BaggingClassifier: trained
# KNeighborsClassifier: trained
# MLPClassifier: trained
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/bagging.py:623: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/multilayer_perceptron.py:921: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
models
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=None, splitter='best'),
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                         max_depth=None, max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=10,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False),
#  BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                    max_features=1.0, max_samples=1.0, n_estimators=10,
#                    n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                    warm_start=False),
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                       metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                       weights='uniform'),
#  MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#                beta_2=0.999, early_stopping=False, epsilon=1e-08,
#                hidden_layer_sizes=(100,), learning_rate='constant',
#                learning_rate_init=0.001, max_iter=200, momentum=0.9,
#                n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#                random_state=None, shuffle=True, solver='adam', tol=0.0001,
#                validation_fraction=0.1, verbose=False, warm_start=False)]

# %%
#classification report
from sklearn.metrics import classification_report
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: classification_report = {classification_report(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.51      0.52      0.51        66
#          3.0       0.61      0.60      0.61        83
#
#     accuracy                           0.56       149
#    macro avg       0.56      0.56      0.56       149
# weighted avg       0.56      0.56      0.56       149
#
#
# RandomForestClassifier: classification_report =               precision    recall  f1-score   support
#
#          1.0       0.65      0.47      0.54        66
#          3.0       0.65      0.80      0.72        83
#
#     accuracy                           0.65       149
#    macro avg       0.65      0.63      0.63       149
# weighted avg       0.65      0.65      0.64       149
#
#
# BaggingClassifier     : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.55      0.61      0.58        66
#          3.0       0.66      0.60      0.63        83
#
#     accuracy                           0.60       149
#    macro avg       0.60      0.60      0.60       149
# weighted avg       0.61      0.60      0.61       149
#
#
# KNeighborsClassifier  : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        66
#          3.0       0.56      1.00      0.72        83
#
#     accuracy                           0.56       149
#    macro avg       0.28      0.50      0.36       149
# weighted avg       0.31      0.56      0.40       149
#
#
# MLPClassifier         : classification_report =               precision    recall  f1-score   support
#
#          1.0       0.44      1.00      0.61        66
#          3.0       0.00      0.00      0.00        83
#
#     accuracy                           0.44       149
#    macro avg       0.22      0.50      0.31       149
# weighted avg       0.20      0.44      0.27       149
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: confusion_matrix(= {confusion_matrix(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: confusion_matrix(= [[34 32]
#  [33 50]]
#
# RandomForestClassifier: confusion_matrix(= [[31 35]
#  [17 66]]
#
# BaggingClassifier     : confusion_matrix(= [[40 26]
#  [33 50]]
#
# KNeighborsClassifier  : confusion_matrix(= [[ 0 66]
#  [ 0 83]]
#
# MLPClassifier         : confusion_matrix(= [[66  0]
#  [83  0]]

# %%
#roc_auc score
from sklearn.metrics import roc_auc_score
for model in models:
    Y_pred = model.predict(X_test)
    print(
    f"{model.__class__.__name__:22}: roc_auc_score(= {roc_auc_score(Y_test, Y_pred)} \n"
    )
# Out:
# DecisionTreeClassifier: roc_auc_score(= 0.558780576852866
#
# RandomForestClassifier: roc_auc_score(= 0.632438846294268
#
# BaggingClassifier     : roc_auc_score(= 0.6042351223074115
#
# KNeighborsClassifier  : roc_auc_score(= 0.5
#
# MLPClassifier         : roc_auc_score(= 0.5

# %%
t2 = pd.DataFrame(Y_pred)
t2.value_counts()
# Out:
# 1.0    149
# dtype: int64
